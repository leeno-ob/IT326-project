# %% [markdown]
# <a href="https://colab.research.google.com/github/leeno-ob/IT326-project/blob/main/Phase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Phase 2 – Data Analysis
## Statistical Summary and Outlier Detection

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/leeno-ob/IT326-project/refs/heads/main/Dataset/Raw_dataset.csv"
df = pd.read_csv(url)

df.head()

df.describe()

score = df["Exam_Score"]

minimum = score.min()
Q1 = score.quantile(0.25)
median = score.median()
Q3 = score.quantile(0.75)
maximum = score.max()

print("Minimum:", minimum)
print("Q1:", Q1)
print("Median:", median)
print("Q3:", Q3)
print("Maximum:", maximum)

IQR = Q3 - Q1
print("IQR:", IQR)

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

outliers = df[(score < lower_bound) | (score > upper_bound)]
print("Number of outliers:", len(outliers))

plt.figure(figsize=(6,4))
sns.boxplot(x=df["Exam_Score"])
plt.title("Boxplot of Exam Score")
plt.show()
# Out:
# Minimum: 55
# Q1: 65.0
# Median: 67.0
# Q3: 69.0
# Maximum: 101
# IQR: 4.0
# Lower Bound: 59.0
# Upper Bound: 75.0
# Number of outliers: 104
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-391875132.py in <cell line: 0>()
#      34 print("Number of outliers:", len(outliers))
#      35
# ---> 36 plt.figure(figsize=(6,4))
#      37 sns.boxplot(x=df["Exam_Score"])
#      38 plt.title("Boxplot of Exam Score")
#
# NameError: name 'plt' is not defined
