# %% [markdown]
# <a href="https://colab.research.google.com/github/leeno-ob/IT326-project/blob/main/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("../Dataset/Raw_dataset.csv")

# Number and data types of attributes
print("Number of attributes (features):", df.shape[1])
print("\nData types of attributes:\n")
print(df.dtypes)

# Number of objects (records)
print("\nNumber of objects (instances/records):", df.shape[0])

# Class label information
class_label = "Exam_Score"
print("\nClass label:", class_label)
print("\nCounts for each value in the class label:\n")
print(df[class_label].value_counts())

# Print sample of raw dataset (as in slides)
df.head()
